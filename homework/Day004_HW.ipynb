# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json

r = requests.get('https://api.github.com/events')

print('r.text\n')
r.text
# Out:
# r.text
# m/repos/herve-coder/TypeScript-React-Starter","forks_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/forks","keys_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/keys{/key_id}","collaborators_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/teams","hooks_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/hooks","issue_events_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/issues/events{/number}","events_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/events","assignees_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/assignees{/user}","branches_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/branches{/branch}","tags_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/tags","blobs_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/git/refs{/sha}","trees_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/git/trees{/sha}","statuses_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/statuses/{sha}","languages_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/languages","stargazers_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/stargazers","contributors_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/contributors","subscribers_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/subscribers","subscription_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/subscription","commits_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/commits{/sha}","git_commits_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/git/commits{/sha}","comments_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/comments{/number}","issue_comment_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/issues/comments{/number}","contents_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/contents/{+path}","compare_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/compare/{base}...{head}","merges_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/merges","archive_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/downloads","issues_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/issues{/number}","pulls_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/pulls{/number}","milestones_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/milestones{/number}","notifications_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/labels{/name}","releases_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/releases{/id}","deployments_url":"https://api.github.com/repos/herve-coder/TypeScript-React-Starter/deployments","created_at":"2019-12-01T07:25:56Z","updated_at":"2019-12-01T04:54:32Z","pushed_at":"2019-08-23T00:06:50Z","git_url":"git://github.com/herve-coder/TypeScript-React-Starter.git","ssh_url":"git@github.com:herve-coder/TypeScript-React-Starter.git","clone_url":"https://github.com/herve-coder/TypeScript-React-Starter.git","svn_url":"https://github.com/herve-coder/TypeScript-React-Starter","homepage":null,"si ...

# %%
import requests
import json

r = requests.get('https://api.github.com/events')

print('json.loads(r.text)\n')
json.loads(r.text)
# Out:
# json.loads(r.text)
# epos/acid-chicken/iMast/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/acid-chicken/iMast/languages',
#       'stargazers_url': 'https://api.github.com/repos/acid-chicken/iMast/stargazers',
#       'contributors_url': 'https://api.github.com/repos/acid-chicken/iMast/contributors',
#       'subscribers_url': 'https://api.github.com/repos/acid-chicken/iMast/subscribers',
#       'subscription_url': 'https://api.github.com/repos/acid-chicken/iMast/subscription',
#       'commits_url': 'https://api.github.com/repos/acid-chicken/iMast/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/acid-chicken/iMast/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/acid-chicken/iMast/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/acid-chicken/iMast/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/acid-chicken/iMast/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/acid-chicken/iMast/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/acid-chicken/iMast/merges',
#       'archive_url': 'https://api.github.com/repos/acid-chicken/iMast/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/acid-chicken/iMast/downloads',
#       'issues_url': 'https://api.github.com/repos/acid-chicken/iMast/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/acid-chicken/iMast/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/acid-chicken/iMast/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/acid-chicken/iMast/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/acid-chicken/iMast/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/acid-chicken/iMast/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/acid-chicken/iMast/deployments',
#       'created_at': '2019-10-26T10:26:37Z',
#       'updated_at': '2019-12-01T05:26:27Z',
#       'pushed_at': '2019-12-01T05:26:24Z',
#       'git_url': 'git://github.com/acid-chicken/iMast.git',
#       'ssh_url': 'git@github.com:acid-chicken/iMast.git',
#       'clone_url': 'https://github.com/acid-chicken/iMast.git',
#       'svn_url': 'https://github.com/acid-chicken/iMast',
#       'homepage': 'https://cinderella-project.github.io/iMast/',
#       'size': 4395,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Swift',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/acid-chicken/iMast/pulls/22'},
#      'html': {'href': 'https://github.com/acid-chicken/iMast/pull/22'},
#      'issue': {'href': 'https://api.github.com/repos/acid-chicken/iMast/issues/22'},
#      'comments': {'href': 'https://api.github.com/repos/acid-chicken/iMast/issues/22/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/acid-chicken/iMast/pulls/22/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/acid-chicken/iMast/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/acid-chicken/iMast/pulls/22/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/acid-chicken/iMast/statuses/4efbce6658c5ed978c0cd7dfa26ece177c4f14d9'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 48,
#     'deletions': 141,
#     'changed_files': 12}},
#   'public': True,
#   'created_at': '2019-12-01T07:26:24Z'},
#  {'id': '10982424976',
#   'type': 'PushEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 217534341,
#    'name': 'sayboras/cli',
#    'url': 'https://api.github.com/repos/sayboras/cli'},
#   'payload': {'push_id': 4339819079,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': 'eb1b3bfa7cea1a6071f042f34390bfad716e8c40',
#    'before': '24557c24655ef5862d8f016d566b3518c17a1e6e',
#    'commits': [{'sha': '7f5fdf176c6c44934ff59d32ac1470f3ff6c926b',
#      'author': {'email': 'shaggygi97@gmail.com', 'name': 'shaggygi'},
#      'message': 'Cleaned up a few comments and strings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sayboras/cli/commits/7f5fdf176c6c44934ff59d32ac1470f3ff6c926b'},
#     {'sha': 'aa5d68e2c6b013b219fdc6082abe97743a8ef60c',
#      'author': {'email': 'artursouza.ms@outlook.com', 'name': 'Artur Souza'},
#      'message': 'Merge pull request #217 from shaggygi/add-period\n\nClean up a few comments and strings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sayboras/cli/commits/aa5d68e2c6b013b219fdc6082abe97743a8ef60c'},
#     {'sha': 'eb1b3bfa7cea1a6071f042f34390bfad716e8c40',
#      'author': {'email': 'shaggygi97@gmail.com', 'name': 'Greg Ingram'},
#      'message': 'Added filter for Visual Studio (#216)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sayboras/cli/commits/eb1b3bfa7cea1a6071f042f34390bfad716e8c40'}]},
#   'public': True,
#   'created_at': '2019-12-01T07:26:24Z'},
#  {'id': '10982424973',
#   'type': 'PushEvent',
#   'actor': {'id': 17193977,
#    'login': 'newstools',
#    'display_login': 'newstools',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/newstools',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17193977?'},
#   'repo': {'id': 164811197,
#    'name': 'newstools/2019-national-daily-nigeria',
#    'url': 'https://api.github.com/repos/newstools/2019-national-daily-nigeria'},
#   'payload': {'push_id': 4339819077,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f2cdfb2383bec7647d88136adf5fbc507dca11c4',
#    'before': '0696e396c4495ce3d20bd0d02cebe7d91a0a3dca',
#    'commits': [{'sha': 'f2cdfb2383bec7647d88136adf5fbc507dca11c4',
#      'author': {'email': 'github@newstools.co.za', 'name': 'NewsTools'},
#      'message': 'Created Text For URL [nationaldailyng.com/man-utd-goalkeeper-reveals-secret-about-team/]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/newstools/2019-national-daily-nigeria/commits/f2cdfb2383bec7647d88136adf5fbc507dca11c4'}]},
#   'public': True,
#   'created_at': '2019-12-01T07:26:24Z'},
#  {'id': '10982424975',
#   'type': 'CreateEvent',
#   'actor': {'id': 54884472,
#    'login': 'vredkin',
#    'display_login': 'vredkin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vredkin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54884472?'},
#   'repo': {'id': 222610537,
#    'name': 'vredkin/1163977-taskmanager-10',
#    'url': 'https://api.github.com/repos/vredkin/1163977-taskmanager-10'},
#   'payload': {'ref': 'module3-task1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Владимир Редькин',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T07:26:24Z'},
#  {'id': '10982424971',
#   'type': 'DeleteEvent',
#   'actor': {'id': 15952883,
#    'login': 'mahidCse',
#    'display_login': 'mahidCse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mahidCse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15952883?'},
#   'repo': {'id': 173438061,
#    'name': 'eilishere/SCHM',
#    'url': 'https://api.github.com/repos/eilishere/SCHM'},
#   'payload': {'ref': 'bugfixes/339-Dashboard-Chart',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'},
#  {'id': '10982424968',
#   'type': 'PushEvent',
#   'actor': {'id': 37809077,
#    'login': 'kageruo',
#    'display_login': 'kageruo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kageruo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37809077?'},
#   'repo': {'id': 196127265,
#    'name': 'kageruo/elasticsearch',
#    'url': 'https://api.github.com/repos/kageruo/elasticsearch'},
#   'payload': {'push_id': 4339819073,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/patch-1',
#    'head': 'a41ae3221f647f33dac111ee354fc1dad30e1b86',
#    'before': '62a891bfa3369018b08fb6f85173507d860e1f43',
#    'commits': [{'sha': 'a41ae3221f647f33dac111ee354fc1dad30e1b86',
#      'author': {'email': '37809077+kageruo@users.noreply.github.com',
#       'name': 'kageruo'},
#      'message': 'translate skip-set-kernel-parameters.asciidoc\n\nby qibao',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kageruo/elasticsearch/commits/a41ae3221f647f33dac111ee354fc1dad30e1b86'}]},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'},
#  {'id': '10982424966',
#   'type': 'CreateEvent',
#   'actor': {'id': 57826736,
#    'login': 'a358254016',
#    'display_login': 'a358254016',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/a358254016',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57826736?'},
#   'repo': {'id': 225122632,
#    'name': 'a358254016/demo-test',
#    'url': 'https://api.github.com/repos/a358254016/demo-test'},
#   'payload': {'ref': 'dev2',
#    'ref_type': 'branch',
#    'master_branch': 'dev2',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'},
#  {'id': '10982424965',
#   'type': 'PushEvent',
#   'actor': {'id': 455023,
#    'login': 'mgechev',
#    'display_login': 'mgechev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mgechev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/455023?'},
#   'repo': {'id': 155446736,
#    'name': 'mgechev/revive.run',
#    'url': 'https://api.github.com/repos/mgechev/revive.run'},
#   'payload': {'push_id': 4339819071,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a12334b01efdbc01393ebe22e897d8f63cb63a28',
#    'before': '7099812ad2bedbbe05a17c94ed5c59d06c803847',
#    'commits': [{'sha': 'a12334b01efdbc01393ebe22e897d8f63cb63a28',
#      'author': {'email': 'mgechev@gmail.com', 'name': 'mgechev'},
#      'message': 'Travis CI deployment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mgechev/revive.run/commits/a12334b01efdbc01393ebe22e897d8f63cb63a28'}]},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'},
#  {'id': '10982424963',
#   'type': 'PushEvent',
#   'actor': {'id': 16307144,
#    'login': '5john',
#    'display_login': '5john',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/5john',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16307144?'},
#   'repo': {'id': 211601139,
#    'name': '5john/5john',
#    'url': 'https://api.github.com/repos/5john/5john'},
#   'payload': {'push_id': 4339819064,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5f0db9616f3b6fed480efc2e182d1aae9696702f',
#    'before': '21ed8e58e8b052eea383844fe4e6c25f20575ac9',
#    'commits': [{'sha': '5f0db9616f3b6fed480efc2e182d1aae9696702f',
#      'author': {'email': '397633614@qq.com', 'name': '5john'},
#      'message': '2019/12/01 07:26:19    h02_5fcy@linshiyouxiang.net',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/5john/5john/commits/5f0db9616f3b6fed480efc2e182d1aae9696702f'}]},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'},
#  {'id': '10982424961',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 17346126,
#    'login': 'alchokem',
#    'display_login': 'alchokem',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alchokem',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17346126?'},
#   'repo': {'id': 3988410,
#    'name': 'TeamWin/Team-Win-Recovery-Project',
#    'url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project/issues/1534',
#     'repository_url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project',
#     'labels_url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project/issues/1534/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project/issues/1534/comments',
#     'events_url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project/issues/1534/events',
#     'html_url': 'https://github.com/TeamWin/Team-Win-Recovery-Project/issues/1534',
#     'id': 530650065,
#     'node_id': 'MDU6SXNzdWU1MzA2NTAwNjU=',
#     'number': 1534,
#     'title': '"Up a Level" in File Manager Not Working',
#     'user': {'login': 'alchokem',
#      'id': 17346126,
#      'node_id': 'MDQ6VXNlcjE3MzQ2MTI2',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/17346126?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alchokem',
#      'html_url': 'https://github.com/alchokem',
#      'followers_url': 'https://api.github.com/users/alchokem/followers',
#      'following_url': 'https://api.github.com/users/alchokem/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alchokem/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alchokem/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alchokem/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alchokem/orgs',
#      'repos_url': 'https://api.github.com/users/alchokem/repos',
#      'events_url': 'https://api.github.com/users/alchokem/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alchokem/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2019-12-01T00:45:23Z',
#     'updated_at': '2019-12-01T07:26:23Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': '- [X ] I am running an official build of TWRP, downloaded from https://twrp.me/Devices/\r\n- [X ] I am running the latest version of TWRP\r\n- [ X] I have read the FAQ (https://twrp.me/FAQ/)\r\n- [ X] I have searched for my issue and it does not already exist\r\n\r\n**Device codename**: <HTC 10>\r\n**TWRP version**: <3.3.1>\r\n\r\n#### WHAT STEPS WILL REPRODUCE THE PROBLEM?\r\nBoot Into TWRP Recovery -> Advanced -> File Manager -> Select any Folder (Folder Contents is Displayed) -> Select "Up A Level"\r\n\r\n#### WHAT IS THE EXPECTED RESULT?\r\nShould Navigate back up the Folder Tree\r\n\r\n#### WHAT HAPPENS INSTEAD?\r\nNothing at all.\r\n\r\n#### ADDITIONAL INFORMATION\r\n Happens with older versions as well.\r\n\r\n<!-- Use https://paste.omnirom.org/ and upload `/tmp/recovery.log` and the output of `dmesg` -->\r\n`/tmp/recovery.log`: <!-- Link here -->\r\n`dmesg`: <!-- Link here -->\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project/issues/comments/560068780',
#     'html_url': 'https://github.com/TeamWin/Team-Win-Recovery-Project/issues/1534#issuecomment-560068780',
#     'issue_url': 'https://api.github.com/repos/TeamWin/Team-Win-Recovery-Project/issues/1534',
#     'id': 560068780,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MDA2ODc4MA==',
#     'user': {'login': 'alchokem',
#      'id': 17346126,
#      'node_id': 'MDQ6VXNlcjE3MzQ2MTI2',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/17346126?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alchokem',
#      'html_url': 'https://github.com/alchokem',
#      'followers_url': 'https://api.github.com/users/alchokem/followers',
#      'following_url': 'https://api.github.com/users/alchokem/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alchokem/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alchokem/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alchokem/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alchokem/orgs',
#      'repos_url': 'https://api.github.com/users/alchokem/repos',
#      'events_url': 'https://api.github.com/users/alchokem/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alchokem/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-01T07:26:22Z',
#     'updated_at': '2019-12-01T07:26:22Z',
#     'author_association': 'NONE',
#     'body': 'One more observance:  I can\'t select "Reboot after installation is complete" (second Line in Settings -> General).If I scroll the display up one row, I can select "Reboot....". I also cannot select "UTC-11..." under Settings -> Time Zone.   With the phone fully booted to Oreo, there is no discernible "dead spots" on the screen.'}},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z',
#   'org': {'id': 638707,
#    'login': 'TeamWin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/TeamWin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/638707?'}},
#  {'id': '10982424958',
#   'type': 'PushEvent',
#   'actor': {'id': 1647735,
#    'login': 'idstam',
#    'display_login': 'idstam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idstam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1647735?'},
#   'repo': {'id': 112704305,
#    'name': 'idstam/aoc_idstam',
#    'url': 'https://api.github.com/repos/idstam/aoc_idstam'},
#   'payload': {'push_id': 4339819066,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '99059bf4e3ae52e371a4f945605038eada31862d',
#    'before': 'adac5d776b98fc50f8d7f9aea65a38e8af419a59',
#    'commits': [{'sha': '99059bf4e3ae52e371a4f945605038eada31862d',
#      'author': {'email': 'johan@idstam.com', 'name': 'Johan Idstam'},
#      'message': '2019 Day 1.2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/idstam/aoc_idstam/commits/99059bf4e3ae52e371a4f945605038eada31862d'}]},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'},
#  {'id': '10982424959',
#   'type': 'CreateEvent',
#   'actor': {'id': 304383,
#    'login': 'jasonharrison',
#    'display_login': 'jasonharrison',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jasonharrison',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/304383?'},
#   'repo': {'id': 221994970,
#    'name': 'jasonharrison/Snoostorm',
#    'url': 'https://api.github.com/repos/jasonharrison/Snoostorm'},
#   'payload': {'ref': 'fix-mentions',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'An event based library for streaming from the Reddit API. Built on top of snoowrap',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'},
#  {'id': '10982424956',
#   'type': 'PushEvent',
#   'actor': {'id': 36951112,
#    'login': 'jembsd',
#    'display_login': 'jembsd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jembsd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36951112?'},
#   'repo': {'id': 225077853,
#    'name': 'jembsd/jembsd.github.io',
#    'url': 'https://api.github.com/repos/jembsd/jembsd.github.io'},
#   'payload': {'push_id': 4339819065,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6124540afaf8f302051041de91217a7f7323748d',
#    'before': '1f595bc2f2024af010f6a8ac57ba190138f07047',
#    'commits': [{'sha': '6124540afaf8f302051041de91217a7f7323748d',
#      'author': {'email': 'joel.emond@icloud.com', 'name': 'Joel'},
#      'message': 'init',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jembsd/jembsd.github.io/commits/6124540afaf8f302051041de91217a7f7323748d'}]},
#   'public': True,
#   'created_at': '2019-12-01T07:26:23Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# pine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":1,"userUpvoted":null},{"_id":"5c72d9b651021f001415f00c","text":"Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.","type":"cat","user":{"_id":"5c6fd96df4256a001498a73f","name":{"first":"Hedvig","last":"Annersten"}},"upvotes":1,"userUpvoted":null},{"_id":"5c72dbd851021f001415f010","text":"The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.","type":"cat","user":{"_id":"5c72dbb751021f001415f00f","name":{"first":"Hedvig","last":"Annersten"}},"upvotes":1,"userUpvoted":null},{"_id":"5c7408a14dd87d001490f02b","text":"The cheetah is the only cat that doesn\'t have retractable claws.","type":"cat","user":{"_id":"5c72e94751021f001415f012","name":{"first":"Tests","last":"HiQ"}},"upvotes":1,"userUpvoted":null},{"_id":"5c75f56272681400147b988a","text":"There are only two escalators in the state of Wyoming.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":1,"userUpvoted":null},{"_id":"5c84248f731a60001540a193","text":"When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, \\"elevator butt\\" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.","type":"cat","user":{"_id":"5c7da4bd70008708fb17c88f","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":1,"userUpvoted":null},{"_id":"5c87d03dec1e5c0aa37e0a6b","type":"cat","text":"On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made \\"a valuable contribution to research.\\".","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":1,"userUpvoted":null},{"_id":"5cd42b77cfdf230015bd7a45","text":"Cats can sense distress from a human being.","type":"cat","user":{"_id":"5cd42b40cfdf230015bd7a44","name":{"first":"Chloe","last":"Simmons"}},"upvotes":1,"userUpvoted":null},{"_id":"5cd86b0e1dc6d50015ec2f08","text":"Norwegian Forest Cats are usually very people friendly.","type":"cat","user":{"_id":"5cd86adb1dc6d50015ec2f07","name":{"first":"Shay","last":"Zhang"}},"upvotes":1,"userUpvoted":null},{"_id":"5d38afd60f1c57001592f127","type":"cat","text":"In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":1,"userUpvoted":null},{"_id":"5d38b0310f1c57001592f128","type":"cat","text":"Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":1,"userUpvoted":null},{"_id":"5d38b0c40f1c57001592f129","type":"cat","text":"The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":1,"userUpvoted":null},{"_id":"5d38b1290f1c57001592f12a","type":"ca ...

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# me': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1290f1c57001592f12a',
#    'type': 'cat',
#    'text': 'Bobtail cats owe their shortened tails to a natural genetic mutation that has appeared in cats across time and in various regions of the world. The American Bobtail can be traced back to Yodi, a cat with the mutation that was found in Arizona in the 1960s. Yodi passed the genetic quirk on to his kittens, thus creating a new breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
